# %%
import numpy as np

# %%
# нейрон дотстаточно описать весами его нейронов и значением биаса, реализуем это

# Количество весом у нейрона
n = 3

# Генерация случайных весов
W = np.random.rand(n)
b = np.random.rand(1)
W_copy = W.copy()
b_copy = b.copy()

# Количество случайных наборов данных
k = 5

# Генерация случайных наборов данных
X = np.random.rand(k, n)-0.5

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def perceptron_sigmoid_output(inputs, weights, bias):
    # Рассчитываем взвешенную сумму входов
    z = np.dot(inputs, weights) + bias

    # Применяем функцию активации
    output = sigmoid(z)

    return output

def perceptron_class_output(inputs, weights, bias):
 return 1 if np.dot(inputs, weights) + bias > 0.5 else 0

# %%
# попробуем пропустить через наш нейрон данные 
print(" через сигмоиду ")
for x in X:
    result = perceptron_sigmoid_output(x, W, b)
    print(f"Input: {x}, Output: {result}")
    
print(" через классическую функцию персептрона ")
for x in X:
    result = perceptron_class_output(x, W, b)
    print(f"Input: {x}, Output: {result}")
# персептроны способны классифицировать линейно разделимые образы, и для этого используют функцию как в 
# perceptron_class_output, однако для нейрона можно использовать любые функции активации, и их налажение друг на друга уже будет нейросетью
# Out:
#  через сигмоиду
# Input: [ 2.65042699e-04 -3.24410530e-01 -4.34760108e-01], Output: [0.49980011]
# Input: [-0.01647986 -0.20102677  0.11855638], Output: [0.57161639]
# Input: [0.4551922  0.4489519  0.10726176], Output: [0.74428814]
# Input: [ 0.36987181 -0.37673854 -0.42921917], Output: [0.54345274]
# Input: [0.05552707 0.3293205  0.13153546], Output: [0.67954158]
#  через классическую функцию персептрона
# Input: [ 2.65042699e-04 -3.24410530e-01 -4.34760108e-01], Output: 0
# Input: [-0.01647986 -0.20102677  0.11855638], Output: 0
# Input: [0.4551922  0.4489519  0.10726176], Output: 1
# Input: [ 0.36987181 -0.37673854 -0.42921917], Output: 0
# Input: [0.05552707 0.3293205  0.13153546], Output: 1

# %%
# Решим задачу на  определение положения точки относительно полигона
# удобная функция для создания персептрона, который задает прямую y= k*x + bias

def create_perceptron(k,bias):
    return np.array([-k, 1, -bias])


# позволяет показать нашу гиперплоскость
def draw_line(weights):
    f = [ -w[2]/w[1], -1*w[0]/w[1]-w[2]/w[1]]
    plt.plot(f)

# эта функция рисует разделяющую гиперплоскость а так же данные разделяя их на классы
def draw_line_with_info(X, weights):
    
    def perceptron_class_output(inputs, weights):
         return 1 if np.dot(inputs, weights) >= 0 else 0
        
    draw_line(weights)
    for i in range(N):
        x = np.array([X[0][i], X[1][i], 1])
        y = perceptron_class_output(x, weights)
        if y == 0 :
            plt.scatter(X[0][i], X[1][i], s = 10, c ='blue')
        else:
            plt.scatter(X[0][i], X[1][i], s = 10, c ='red')

#опишем случайное множество точек на [0,1]
N = 100
x1 = np.random.random(N)
x2 = x1 + [(np.random.random()-0.5)*2 for i in range(N)] + 0.01
X = [x1,x2]

w = create_perceptron(1,0.5)

draw_line_with_info(X, w)
plt.grid(True)
plt.show()

# %%
# определим наш полигон

w1 = create_perceptron(0.5 , -2)
w2 = create_perceptron(-1.5, 1.5)
w3 = create_perceptron(3, -0.5)
w4 = create_perceptron(-7, 5)
w5 = create_perceptron(-8, 2)
W_polygon = [w1, w2, w3, w4, w5]

def draw_lines(W):
    for w in W:
      plt.plot([ -w[2]/w[1], -1*w[0]/w[1]-w[2]/w[1]])

#что бы определить наш полигон, нам необходимо что бы различные гиперплоскости что его определяют выдавали классификацию по разному
# "нижние" гиперплоскости должны выдавать 1 когда точка выше их
# "верхние" гиперплоскости должны выдавать 1 когда точка ниже их
# для каждой грани определим является ли она нижней или верхней
Top = [0,1,1,1,0]

def get_points_in_polygon(W,Top, X):

    def perceptron_class_output(inputs, weights):
     return 1 if np.dot(inputs, weights) >= 0 else 0
    
    def reversed_perceptron_class_output(inputs, weights):
     return 0 if np.dot(inputs, weights) >= 0 else 1
    
    draw_lines(W)
    for i in range(N):
        x = np.array([X[0][i], X[1][i], 1])
        bool = []
        for k, w in enumerate(W):
            if Top[k] ==1:
                bool.append(perceptron_class_output(x,w))
            else:
                bool.append(reversed_perceptron_class_output(x,w))
                
        if all(x == 0 for x in bool):
            plt.scatter(X[0][i], X[1][i], s = 10, c ='blue')
        else:
            plt.scatter(X[0][i], X[1][i], s = 10, c ='red')
        bool = []

N = 300
x1 = np.random.random(N)
x2 = x1 + [(np.random.random()-0.5)*8 for i in range(N)] + 0.01
X = [x1, x2]

get_points_in_polygon(W_polygon, Top, X)

plt.grid(True)
plt.show()

# %%
x_range = np.arange(0, 1.2, 0.025) 
y_range = np.arange(-4, 4.4, 0.2) 

points = [(x, y) for x in x_range for y in y_range]

def get_points_in_polygon(W,Top, X):

    def perceptron_class_output(inputs, weights):
     return 1 if np.dot(inputs, weights) >= 0 else 0
    
    def reversed_perceptron_class_output(inputs, weights):
     return 0 if np.dot(inputs, weights) >= 0 else 1
    
    draw_lines(W)
    pepe = round((1.2/0.025)*(8.4/0.2))
    print(pepe)
    for i in range(pepe):
        x = np.array([X[i][0], X[i][1], 1])
        bool = []
        for k, w in enumerate(W):
            if Top[k] ==1:
                bool.append(perceptron_class_output(x,w))
            else:
                bool.append(reversed_perceptron_class_output(x,w))
                
        if all(x == 0 for x in bool):
            plt.scatter(X[i][0], X[i][1], s = 10, c ='blue')
        else:
            plt.scatter(X[i][0], X[i][1], s = 10, c ='red')
        bool = []
get_points_in_polygon(W_polygon, Top, points)
# Out:
# 2016

# %%
#попробуем обучить нашу нейронную сеть

#пусть у нас есть некоторая обучающая выборка данных
X_train = np.random.rand(k, n)
X_test = np.random.rand(k, n)

# и их соответствующие метки классов (0 или 1)
y_train = np.random.randint(2, size=k)
y_test = np.random.randint(2, size=k)

# %%
# процесс обучения лучше виден для сигмоидальной функции, так что напишем для нее простую градиентную тренировку

def compute_sigmoidal_test_error(X_test, y_test, W, b):
    total_error = 0

    for i in range(len(X_test)):
        output = perceptron_sigmoid_output(X_test[i], W, b)
        error = y_test[i] - output
        total_error += abs(error)

    return total_error

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

def simple_gradient_train(epochs, X_train, y_train, W, b, learning_rate, X_test =None, y_test=None):
    k, n = X_train.shape  # Получаем размерности X_train

    first_error = 0
    # Создаем список для сохранения ошибок на каждой эпохе
    train_errors = []
    test_errors = []

    for epoch in range(epochs):
        total_train_error = 0  # Суммарная ошибка на обучающей выборке на текущей эпохе
        for i in range(k):
            # Вычисление выхода нейросети
            inputs = X_train[i]
            output = perceptron_sigmoid_output(inputs, W,b)
        
             # Вычисление ошибки с использованием производной сигмоидной функции
            error = y_train[i] - output
            total_train_error += abs(error)
            
            # Обновление весов и смещения с помощью градиентного спуска
            gradient = error * sigmoid_derivative(output)
            W += learning_rate * gradient * inputs
            b += learning_rate * gradient
        
        if X_test is not None:
            total_test_error = compute_sigmoidal_test_error(X_test, y_test, W, b)
            test_error_rounded = np.round(total_test_error, 4)
            test_errors.append(test_error_rounded)
        total_train_error_rounded = np.round(total_train_error, 4)   
        train_errors.append(total_train_error_rounded)


        if X_test is not None:
            print(f"Epoch {epoch + 1}/{epochs}, Train Error: {total_train_error_rounded}, Test Error: {test_error_rounded}")
        else:
            print(f"Epoch {epoch + 1}/{epochs}, Train Error: {total_train_error_rounded}")
            
    if X_test is not None:
        return W, b, train_errors,test_errors
    else:
         return W, b, train_errors

# %%
W, b, train_errors, test_errors = simple_gradient_train(1000, X_train, y_train, W=W, b=b, learning_rate=0.1, X_test = X_test, y_test = y_test)
# Out:
# Epoch 1/1000, Train Error: [2.7547], Test Error: [2.3548]
# Epoch 2/1000, Train Error: [2.7424], Test Error: [2.368]
# Epoch 3/1000, Train Error: [2.73], Test Error: [2.3809]
# Epoch 4/1000, Train Error: [2.7176], Test Error: [2.3935]
# Epoch 5/1000, Train Error: [2.7054], Test Error: [2.4058]
# Epoch 6/1000, Train Error: [2.6932], Test Error: [2.4177]
# Epoch 7/1000, Train Error: [2.6812], Test Error: [2.4292]
# Epoch 8/1000, Train Error: [2.6694], Test Error: [2.4402]
# Epoch 9/1000, Train Error: [2.6578], Test Error: [2.4508]
# Epoch 10/1000, Train Error: [2.6465], Test Error: [2.461]
# Epoch 11/1000, Train Error: [2.6354], Test Error: [2.4707]
# Epoch 12/1000, Train Error: [2.6247], Test Error: [2.4799]
# Epoch 13/1000, Train Error: [2.6142], Test Error: [2.4886]
# Epoch 14/1000, Train Error: [2.6041], Test Error: [2.4969]
# Epoch 15/1000, Train Error: [2.5943], Test Error: [2.5047]
# Epoch 16/1000, Train Error: [2.5848], Test Error: [2.5121]
# Epoch 17/1000, Train Error: [2.5756], Test Error: [2.5191]
# Epoch 18/1000, Train Error: [2.5668], Test Error: [2.5257]
# Epoch 19/1000, Train Error: [2.5584], Test Error: [2.5318]
# Epoch 20/1000, Train Error: [2.5502], Test Error: [2.5376]
# Epoch 21/1000, Train Error: [2.5424], Test Error: [2.5431]
# Epoch 22/1000, Train Error: [2.5348], Test Error: [2.5481]
# Epoch 23/1000, Train Error: [2.5276], Test Error: [2.5529]
# Epoch 24/1000, Train Error: [2.5207], Test Error: [2.5574]
# Epoch 25/1000, Train Error: [2.514], Test Error: [2.5615]
# Epoch 26/1000, Train Error: [2.5077], Test Error: [2.5654]
# Epoch 619/1000, Train Error: [1.8892], Test Error: [2.4105]
# Epoch 620/1000, Train Error: [1.8888], Test Error: [2.4102]
# Epoch 621/1000, Train Error: [1.8884], Test Error: [2.41]
# Epoch 622/1000, Train Error: [1.8879], Test Error: [2.4097]
# Epoch 623/1000, Train Error: [1.8875], Test Error: [2.4095]
# Epoch 624/1000, Train Error: [1.887], Test Error: [2.4092]
# Epoch 625/1000, Train Error: [1.8866], Test Error: [2.409]
# Epoch 626/1000, Train Error: [1.8861], Test Error: [2.4088]
# Epoch 627/1000, Train Error: [1.8857], Test Error: [2.4085]
# Epoch 628/1000, Train Error: [1.8852], Test Error: [2.4083]
# Epoch 629/1000, Train Error: [1.8848], Test Error: [2.408]
# Epoch 630/1000, Train Error: [1.8844], Test Error: [2.4078]
# Epoch 631/1000, Train Error: [1.8839], Test Error: [2.4075]
# Epoch 632/1000, Train Error: [1.8835], Test Error: [2.4073]
# Epoch 633/1000, Train Error: [1.883], Test Error: [2.407]
# Epoch 634/1000, Train Error: [1.8826], Test Error: [2.4068]
# Epoch 635/1000, Train Error: [1.8822], Test Error: [2.4066]
# Epoch 636/1000, Train Error: [1.8817], Test Error: [2.4063]
# Epoch 637/1000, Train Error: [1.8813], Test Error: [2.4061]
# Epoch 638/1000, Train Error: [1.8809], Test Error: [2.4058]
# Epoch 639/1000, Train Error: [1.8804], Test Error: [2.4056]
# Epoch 640/1000, Train Error: [1.88], Test Error: [2.4054]
# Epoch 641/1000, Train Error: [1.8796], Test Error: [2.4051]
# Epoch 642/1000, Train Error: [1.8791], Test Error: [2.4049]
# Epoch 643/1000, Train Error: [1.8787], Test Error: [2.4046]
# Epoch 644/1000, Train Error: [1.8783], Test Error: [2.4044]
# Epoch 645/1000, Train Error: [1.8779], Test Error: [2.4042]
# Epoch 646/1000, Train Error: [1.8774], Test Error: [2.4039]
# Epoch 647/1000, Train Error: [1.877], Test Error: [2.4037]
# Epoch 648/1000, Train Error: [1.8766], Test Error: [2.4035]
# Epoch 649/1000, Train Error: [1.8762], Test Error: [2.4032]
# Epoch 650/1000, Train Error: [1.8757], Test Error: [2.403]
# Epoch 651/1000, Train Error: [1.8753], Test Error: [2.4027]
# Epoch 652/1000, Train Error: [1.8749], Test Error: [2.4025]
# Epoch 653/1000, Train Error: [1.8745], Test Error: [2.4023]
# Epoch 654/1000, Train Error: [1.874], Test Error: [2.402]
# Epoch 655/1000, Train Error: [1.8736], Test Error: [2.4018]
# Epoch 656/1000, Train Error: [1.8732], Test Error: [2.4016]
# Epoch 657/1000, Train Error: [1.8728], Test Error: [2.4013]
# Epoch 658/1000, Train Error: [1.8724], Test Error: [2.4011]
# Epoch 659/1000, Train Error: [1.8719], Test Error: [2.4009]
# Epoch 660/1000, Train Error: [1.8715], Test Error: [2.4006]
# Epoch 661/1000, Train Error: [1.8711], Test Error: [2.4004]
# Epoch 662/1000, Train Error: [1.8707], Test Error: [2.4002]
# Epoch 663/1000, Train Error: [1.8703], Test Error: [2.3999]
# Epoch 664/1000, Train Error: [1.8699], Test Error: [2.3997]
# Epoch 665/1000, Train Error: [1.8695], Test Error: [2.3995]
# Epoch 666/1000, Train Error: [1.8691], Test Error: [2.3992]
# Epoch 667/1000, Train Error: [1.8686], Test Error: [2.399]
# Epoch 668/1000, Train Error: [1.8682], Test Error: [2.3988]
# Epoch 669/1000, Train Error: [1.8678], Test Error: [2.3985]
# Epoch 670/1000, Train Error: [1.8674], Test Error: [2.3983]
# Epoch 671/1000, Train Error: [1.867], Test Error: [2.3981]
# Epoch 672/1000, Train Error: [1.8666], Test Error: [2.3979]
# Epoch 673/1000, Train Error: [1.8662], Test Error: [2.3976]
# Epoch 674/1000, Train Error: [1.8658], Test Error: [2.3974]
# Epoch 675/1000, Train Error: [1.8654], Test Error: [2.3972]
# Epoch 676/1000, Train Error: [1.865], Test Error: [2.3969]
# Epoch 677/1000, Train Error: [1.8646], Test Error: [2.3967]
# Epoch 678/1000, Train Error: [1.8642], Test Error: [2.3965]
# Epoch 679/1000, Train Error: [1.8638], Test Error: [2.3963]
# Epoch 680/1000, Train Error: [1.8634], Test Error: [2.396]
# Epoch 681/1000, Train Error: [1.863], Test Error: [2.3958]
# Epoch 682/1000, Train Error: [1.8626], Test Error: [2.3956]
# Epoch 683/1000, Train Error: [1.8622], Test Error: [2.3954]
# Epoch 684/1000, Train Error: [1.8618], Test Error: [2.3951]
# Epoch 685/1000, Train Error: [1.8614], Test Error: [2.3949]
# Epoch 686/1000, Train Error: [1.861], Test Error: [2.3947]
# Epoch 687/1000, Train Error: [1.8606], Test Error: [2.3945]
# Epoch 688/1000, Train Error: [1.8602], Test Error: [2.3942]
# Epoch 689/1000, Train Error: [1.8598], Test Error: [2.394]
# Epoch 690/1000, Train Error: [1.8594], Test Error: [2.3938]
# Epoch 691/1000, Train Error: [1.859], Test Error: [2.3936]
# Epoch 692/1000, Train Error: [1.8586], Test Error: [2.3933]
# Epoch 693/1000, Train Error: [1.8582], Test Error: [2.3931]
# Epoch 694/1000, Train Error: [1.8578], Test Error: [2.3929]
# Epoch 695/1000, Train Error: [1.8574], Test Error: [2.3927]
# Epoch 696/1000, Train Error: [1.857], Test Error: [2.3925]
# Epoch 697/1000, Train Error: [1.8567], Test Error: [2.3922]
# Epoch 698/1000, Train Error: [1.8563], Test Error: [2.392]
# Epoch 699/1000, Train Error: [1.8559], Test Error: [2.3918]
# Epoch 700/1000, Train Error: [1.8555], Test Error: [2.3916]
# Epoch 701/1000, Train Error: [1.8551], Test Error: [2.3914]
# Epoch 702/1000, Train Error: [1.8547], Test Error: [2.3911]
# Epoch 703/1000, Train Error: [1.8543], Test Error: [2.3909]
# Epoch 704/1000, Train Error: [1.854], Test Error: [2.3907]
# Epoch 705/1000, Train Error: [1.8536], Test Error: [2.3905]
# Epoch 706/1000, Train Error: [1.8532], Test Error: [2.3903]
# Epoch 707/1000, Train Error: [1.8528], Test Error: [2.39]
# Epoch 708/1000, Train Error: [1.8524], Test Error: [2.3898]
# Epoch 709/1000, Train Error: [1.852], Test Error: [2.3896]
# Epoch 710/1000, Train Error: [1.8517], Test Error: [2.3894]
# Epoch 711/1000, Train Error: [1.8513], Test Error: [2.3892]
# Epoch 712/1000, Train Error: [1.8509], Test Error: [2.389]
# Epoch 713/1000, Train Error: [1.8505], Test Error: [2.3887]
# Epoch 714/1000, Train Error: [1.8501], Test Error: [2.3885]
# Epoch 715/1000, Train Error: [1.8498], Test Error: [2.3883]
# Epoch 716/1000, Train Error: [1.8494], Test Error: [2.3881]
# Epoch 717/1000, Train Error: [1.849], Test Error: [2.3879]
# Epoch 718/1000, Train Error: [1.8486], Test Error: [2.3877]
# Epoch 719/1000, Train Error: [1.8483], Test Error: [2.3875]
# Epoch 720/1000, Train Error: [1.8479], Test Error: [2.3872]
# Epoch 721/1000, Train Error: [1.8475], Test Error: [2.387]
# Epoch 722/1000, Train Error: [1.8472], Test Error: [2.3868]
# Epoch 723/1000, Train Error: [1.8468], Test Error: [2.3866]
# Epoch 724/1000, Train Error: [1.8464], Test Error: [2.3864]
# Epoch 725/1000, Train Error: [1.846], Test Error: [2.3862]
# Epoch 726/1000, Train Error: [1.8457], Test Error: [2.386]
# Epoch 727/1000, Train Error: [1.8453], Test Error: [2.3858]
# Epoch 728/1000, Train Error: [1.8449], Test Error: [2.3855]
# Epoch 729/1000, Train Error: [1.8446], Test Error: [2.3853]
# Epoch 730/1000, Train Error: [1.8442], Test Error: [2.3851]
# Epoch 731/1000, Train Error: [1.8438], Test Error: [2.3849]
# Epoch 732/1000, Train Error: [1.8435], Test Error: [2.3847]
# Epoch 733/1000, Train Error: [1.8431], Test Error: [2.3845]
# Epoch 734/1000, Train Error: [1.8427], Test Error: [2.3843]
# Epoch 735/1000, Train Error: [1.8424], Test Error: [2.3841]
# Epoch 736/1000, Train Error: [1.842], Test Error: [2.3839]
# Epoch 737/1000, Train Error: [1.8416], Test Error: [2.3837]
# Epoch 738/1000, Train Error: [1.8413], Test Error: [2.3834]
# Epoch 739/1000, Train Error: [1.8409], Test Error: [2.3832]
# Epoch 740/1000, Train Error: [1.8406], Test Error: [2.383]
# Epoch 741/1000, Train Error: [1.8402], Test Error: [2.3828]
# Epoch 742/1000, Train Error: [1.8398], Test Error: [2.3826]
# Epoch 743/1000, Train Error: [1.8395], Test Error: [2.3824]
# Epoch 744/1000, Train Error: [1.8391], Test Error: [2.3822]
# Epoch 745/1000, Train Error: [1.8388], Test Error: [2.382]
# Epoch 746/1000, Train Error: [1.8384], Test Error: [2.3818]
# Epoch 747/1000, Train Error: [1.8381], Test Error: [2.3816]
# Epoch 748/1000, Train Error: [1.8377], Test Error: [2.3814]
# Epoch 749/1000, Train Error: [1.8373], Test Error: [2.3812]
# Epoch 750/1000, Train Error: [1.837], Test Error: [2.381]
# Epoch 751/1000, Train Error: [1.8366], Test Error: [2.3808]
# Epoch 752/1000, Train Error: [1.8363], Test Error: [2.3806]
# Epoch 753/1000, Train Error: [1.8359], Test Error: [2.3804]
# Epoch 754/1000, Train Error: [1.8356], Test Error: [2.3802]
# Epoch 755/1000, Train Error: [1.8352], Test Error: [2.3799]
# Epoch 756/1000, Train Error: [1.8349], Test Error: [2.3797]
# Epoch 757/1000, Train Error: [1.8345], Test Error: [2.3795]
# Epoch 758/1000, Train Error: [1.8342], Test Error: [2.3793]
# Epoch 759/1000, Train Error: [1.8338], Test Error: [2.3791]
# Epoch 760/1000, Train Error: [1.8335], Test Error: [2.3789]
# Epoch 761/1000, Train Error: [1.8331], Test Error: [2.3787]
# Epoch 762/1000, Train Error: [1.8328], Test Error: [2.3785]
# Epoch 763/1000, Train Error: [1.8324], Test Error: [2.3783]
# Epoch 764/1000, Train Error: [1.8321], Test Error: [2.3781]
# Epoch 765/1000, Train Error: [1.8317], Test Error: [2.3779]
# Epoch 766/1000, Train Error: [1.8314], Test Error: [2.3777]
# Epoch 767/1000, Train Error: [1.8311], Test Error: [2.3775]
# Epoch 768/1000, Train Error: [1.8307], Test Error: [2.3773]
# Epoch 769/1000, Train Error: [1.8304], Test Error: [2.3771]
# Epoch 770/1000, Train Error: [1.83], Test Error: [2.3769]
# Epoch 771/1000, Train Error: [1.8297], Test Error: [2.3767]
# Epoch 772/1000, Train Error: [1.8293], Test Error: [2.3765]
# Epoch 773/1000, Train Error: [1.829], Test Error: [2.3763]
# Epoch 774/1000, Train Error: [1.8287], Test Error: [2.3761]
# Epoch 775/1000, Train Error: [1.8283], Test Error: [2.3759]
# Epoch 776/1000, Train Error: [1.828], Test Error: [2.3757]
# Epoch 777/1000, Train Error: [1.8276], Test Error: [2.3755]
# Epoch 778/1000, Train Error: [1.8273], Test Error: [2.3753]
# Epoch 779/1000, Train Error: [1.827], Test Error: [2.3751]
# Epoch 780/1000, Train Error: [1.8266], Test Error: [2.3749]
# Epoch 781/1000, Train Error: [1.8263], Test Error: [2.3748]
# Epoch 782/1000, Train Error: [1.826], Test Error: [2.3746]
# Epoch 783/1000, Train Error: [1.8256], Test Error: [2.3744]
# Epoch 784/1000, Train Error: [1.8253], Test Error: [2.3742]
# Epoch 785/1000, Train Error: [1.825], Test Error: [2.374]
# Epoch 786/1000, Train Error: [1.8246], Test Error: [2.3738]
# Epoch 787/1000, Train Error: [1.8243], Test Error: [2.3736]
# Epoch 788/1000, Train Error: [1.824], Test Error: [2.3734]
# Epoch 789/1000, Train Error: [1.8236], Test Error: [2.3732]
# Epoch 790/1000, Train Error: [1.8233], Test Error: [2.373]
# Epoch 791/1000, Train Error: [1.823], Test Error: [2.3728]
# Epoch 792/1000, Train Error: [1.8226], Test Error: [2.3726]
# Epoch 793/1000, Train Error: [1.8223], Test Error: [2.3724]
# Epoch 794/1000, Train Error: [1.822], Test Error: [2.3722]
# Epoch 795/1000, Train Error: [1.8216], Test Error: [2.372]
# Epoch 796/1000, Train Error: [1.8213], Test Error: [2.3718]
# Epoch 797/1000, Train Error: [1.821], Test Error: [2.3716]
# Epoch 798/1000, Train Error: [1.8207], Test Error: [2.3715]
# Epoch 799/1000, Train Error: [1.8203], Test Error: [2.3713]
# Epoch 800/1000, Train Error: [1.82], Test Error: [2.3711]
# Epoch 801/1000, Train Error: [1.8197], Test Error: [2.3709]
# Epoch 802/1000, Train Error: [1.8194], Test Error: [2.3707]
# Epoch 803/1000, Train Error: [1.819], Test Error: [2.3705]
# Epoch 804/1000, Train Error: [1.8187], Test Error: [2.3703]
# Epoch 805/1000, Train Error: [1.8184], Test Error: [2.3701]
# Epoch 806/1000, Train Error: [1.8181], Test Error: [2.3699]
# Epoch 807/1000, Train Error: [1.8177], Test Error: [2.3697]
# Epoch 808/1000, Train Error: [1.8174], Test Error: [2.3695]
# Epoch 809/1000, Train Error: [1.8171], Test Error: [2.3694]
# Epoch 810/1000, Train Error: [1.8168], Test Error: [2.3692]
# Epoch 811/1000, Train Error: [1.8165], Test Error: [2.369]
# Epoch 812/1000, Train Error: [1.8161], Test Error: [2.3688]
# Epoch 813/1000, Train Error: [1.8158], Test Error: [2.3686]
# Epoch 814/1000, Train Error: [1.8155], Test Error: [2.3684]
# Epoch 815/1000, Train Error: [1.8152], Test Error: [2.3682]
# Epoch 816/1000, Train Error: [1.8149], Test Error: [2.368]
# Epoch 817/1000, Train Error: [1.8146], Test Error: [2.3679]
# Epoch 818/1000, Train Error: [1.8142], Test Error: [2.3677]
# Epoch 819/1000, Train Error: [1.8139], Test Error: [2.3675]
# Epoch 820/1000, Train Error: [1.8136], Test Error: [2.3673]
# Epoch 821/1000, Train Error: [1.8133], Test Error: [2.3671]
# Epoch 822/1000, Train Error: [1.813], Test Error: [2.3669]
# Epoch 823/1000, Train Error: [1.8127], Test Error: [2.3667]
# Epoch 824/1000, Train Error: [1.8124], Test Error: [2.3666]
# Epoch 825/1000, Train Error: [1.812], Test Error: [2.3664]
# Epoch 826/1000, Train Error: [1.8117], Test Error: [2.3662]
# Epoch 827/1000, Train Error: [1.8114], Test Error: [2.366]
# Epoch 828/1000, Train Error: [1.8111], Test Error: [2.3658]
# Epoch 829/1000, Train Error: [1.8108], Test Error: [2.3656]
# Epoch 830/1000, Train Error: [1.8105], Test Error: [2.3654]
# Epoch 831/1000, Train Error: [1.8102], Test Error: [2.3653]
# Epoch 832/1000, Train Error: [1.8099], Test Error: [2.3651]
# Epoch 833/1000, Train Error: [1.8096], Test Error: [2.3649]
# Epoch 834/1000, Train Error: [1.8093], Test Error: [2.3647]
# Epoch 835/1000, Train Error: [1.8089], Test Error: [2.3645]
# Epoch 836/1000, Train Error: [1.8086], Test Error: [2.3644]
# Epoch 837/1000, Train Error: [1.8083], Test Error: [2.3642]
# Epoch 838/1000, Train Error: [1.808], Test Error: [2.364]
# Epoch 839/1000, Train Error: [1.8077], Test Error: [2.3638]
# Epoch 840/1000, Train Error: [1.8074], Test Error: [2.3636]
# Epoch 841/1000, Train Error: [1.8071], Test Error: [2.3634]
# Epoch 842/1000, Train Error: [1.8068], Test Error: [2.3633]
# Epoch 843/1000, Train Error: [1.8065], Test Error: [2.3631]
# Epoch 844/1000, Train Error: [1.8062], Test Error: [2.3629]
# Epoch 845/1000, Train Error: [1.8059], Test Error: [2.3627]
# Epoch 846/1000, Train Error: [1.8056], Test Error: [2.3625]
# Epoch 938/1000, Train Error: [1.7797], Test Error: [2.3469]
# Epoch 939/1000, Train Error: [1.7795], Test Error: [2.3468]
# Epoch 940/1000, Train Error: [1.7792], Test Error: [2.3466]
# Epoch 941/1000, Train Error: [1.779], Test Error: [2.3465]
# Epoch 942/1000, Train Error: [1.7787], Test Error: [2.3463]
# Epoch 943/1000, Train Error: [1.7784], Test Error: [2.3461]
# Epoch 944/1000, Train Error: [1.7782], Test Error: [2.346]
# Epoch 945/1000, Train Error: [1.7779], Test Error: [2.3458]
# Epoch 946/1000, Train Error: [1.7777], Test Error: [2.3457]
# Epoch 947/1000, Train Error: [1.7774], Test Error: [2.3455]
# Epoch 948/1000, Train Error: [1.7771], Test Error: [2.3454]
# Epoch 949/1000, Train Error: [1.7769], Test Error: [2.3452]
# Epoch 950/1000, Train Error: [1.7766], Test Error: [2.345]
# Epoch 951/1000, Train Error: [1.7764], Test Error: [2.3449]
# Epoch 952/1000, Train Error: [1.7761], Test Error: [2.3447]
# Epoch 953/1000, Train Error: [1.7759], Test Error: [2.3446]
# Epoch 954/1000, Train Error: [1.7756], Test Error: [2.3444]
# Epoch 955/1000, Train Error: [1.7753], Test Error: [2.3443]
# Epoch 956/1000, Train Error: [1.7751], Test Error: [2.3441]
# Epoch 957/1000, Train Error: [1.7748], Test Error: [2.3439]
# Epoch 958/1000, Train Error: [1.7746], Test Error: [2.3438]
# Epoch 959/1000, Train Error: [1.7743], Test Error: [2.3436]
# Epoch 960/1000, Train Error: [1.7741], Test Error: [2.3435]
# Epoch 961/1000, Train Error: [1.7738], Test Error: [2.3433]
# Epoch 962/1000, Train Error: [1.7736], Test Error: [2.3432]
# Epoch 963/1000, Train Error: [1.7733], Test Error: [2.343]
# Epoch 964/1000, Train Error: [1.7731], Test Error: [2.3429]
# Epoch 965/1000, Train Error: [1.7728], Test Error: [2.3427]
# Epoch 966/1000, Train Error: [1.7726], Test Error: [2.3425]
# Epoch 967/1000, Train Error: [1.7723], Test Error: [2.3424]
# Epoch 968/1000, Train Error: [1.7721], Test Error: [2.3422]
# Epoch 969/1000, Train Error: [1.7718], Test Error: [2.3421]
# Epoch 970/1000, Train Error: [1.7716], Test Error: [2.3419]
# Epoch 971/1000, Train Error: [1.7713], Test Error: [2.3418]
# Epoch 972/1000, Train Error: [1.7711], Test Error: [2.3416]
# Epoch 973/1000, Train Error: [1.7708], Test Error: [2.3415]
# Epoch 974/1000, Train Error: [1.7706], Test Error: [2.3413]
# Epoch 975/1000, Train Error: [1.7703], Test Error: [2.3412]
# Epoch 976/1000, Train Error: [1.7701], Test Error: [2.341]
# Epoch 977/1000, Train Error: [1.7698], Test Error: [2.3409]
# Epoch 978/1000, Train Error: [1.7696], Test Error: [2.3407]
# Epoch 979/1000, Train Error: [1.7693], Test Error: [2.3406]
# Epoch 980/1000, Train Error: [1.7691], Test Error: [2.3404]
# Epoch 981/1000, Train Error: [1.7688], Test Error: [2.3403]
# Epoch 982/1000, Train Error: [1.7686], Test Error: [2.3401]
# Epoch 983/1000, Train Error: [1.7684], Test Error: [2.34]
# Epoch 984/1000, Train Error: [1.7681], Test Error: [2.3398]
# Epoch 985/1000, Train Error: [1.7679], Test Error: [2.3397]
# Epoch 986/1000, Train Error: [1.7676], Test Error: [2.3395]
# Epoch 987/1000, Train Error: [1.7674], Test Error: [2.3393]
# Epoch 988/1000, Train Error: [1.7671], Test Error: [2.3392]
# Epoch 989/1000, Train Error: [1.7669], Test Error: [2.339]
# Epoch 990/1000, Train Error: [1.7667], Test Error: [2.3389]
# Epoch 991/1000, Train Error: [1.7664], Test Error: [2.3387]
# Epoch 992/1000, Train Error: [1.7662], Test Error: [2.3386]
# Epoch 993/1000, Train Error: [1.7659], Test Error: [2.3384]
# Epoch 994/1000, Train Error: [1.7657], Test Error: [2.3383]
# Epoch 995/1000, Train Error: [1.7654], Test Error: [2.3382]
# Epoch 996/1000, Train Error: [1.7652], Test Error: [2.338]
# Epoch 997/1000, Train Error: [1.765], Test Error: [2.3379]
# Epoch 998/1000, Train Error: [1.7647], Test Error: [2.3377]
# Epoch 999/1000, Train Error: [1.7645], Test Error: [2.3376]
# Epoch 1000/1000, Train Error: [1.7642], Test Error: [2.3374]

# %%
#Тут можно заметить как изменилась наша W
print("weights before: \n", W)
print("weights after: \n", W_copy)

print("bias before: \n", b)
print("bias after: \n", b_copy)
# Out:
# weights before:
#  [ 3.64489033 -2.00361223  0.40115393]
# weights after:
#  [0.57939358 0.78582173 0.36505839]
# bias before:
#  [-2.08835345]
# bias after:
#  [0.41268856]

# %%
# Визуализируем процесс обучения
import matplotlib.pyplot as plt

epochs = range(1, 1001)        # Список номеров эпох
def do_plot(epochs,train_errors,test_errors):
    # Построение графика ошибок на обучающем и тестовом наборах
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, train_errors, label='Train_error')
    plt.plot(epochs, test_errors, label='Test_error')
    plt.xlabel('epochs')
    plt.ylabel('Error')
    plt.title('Some error visualisation')
    plt.legend()
    plt.grid(True)
    plt.show()

do_plot(epochs,train_errors,test_errors)

# %%
#теперь напишем более сложную и продвинутую функцию обучения

def compute_class_test_error(X_test, y_test, W, b):
    total_error = 0

    for i in range(len(X_test)):
        output = perceptron_class_output(X_test[i], W, b)
        error = y_test[i] - output
        total_error += abs(error)

    return total_error


def gradient_class_train(epochs, X_train, y_train, W, b, learning_rate, batch_size, X_test =None, y_test=None, shuffle=False, printAll = True):
    k, n = X_train.shape  # Получаем размерности X_train
    num_batches = k // batch_size  # Вычисляем количество мини-пакетов

    first_error = 0
    # Создаем список для сохранения ошибок на каждой эпохе
    train_errors = []
    test_errors = []

    for epoch in range(epochs):
        if shuffle:
            # Перемешиваем данные перед каждой эпохой, если указан параметр shuffle=True
            indices = np.arange(k)
            np.random.shuffle(indices)
            X_train = X_train[indices]
            y_train = y_train[indices]

        total_train_error = 0  # Суммарная ошибка на обучающей выборке на текущей эпохе

        for batch in range(num_batches):
            # Выбираем мини-пакет данных
            start = batch * batch_size
            end = (batch + 1) * batch_size
            X_batch = X_train[start:end]
            y_batch = y_train[start:end]

            for i in range(batch_size):
                # Вычисляем выход персептрона для каждого элемента мини-пакета
                output = perceptron_class_output(X_batch[i], W, b)

                # Вычисляем ошибку
                error = y_batch[i] - output

                # Обновляем веса и биас с помощью градиентного спуска
                # При такой функции градиентом просто является ошибка
                W += learning_rate * error * X_batch[i]
                b += learning_rate * error

                # Суммируем ошибку для текущего наблюдения
                total_train_error += abs(error)

        # Вычисляем ошибку на тестовой выборке
        if X_test is not None:
            total_test_error = compute_class_test_error(X_test, y_test, W, b)
            test_error_rounded = np.round(total_test_error, 4)
            test_errors.append(test_error_rounded)

        # Округляем ошибку 
        total_train_error_rounded = np.round(total_train_error, 4)   
        train_errors.append(total_train_error_rounded)
        
        if first_error == 0:
            first_error = total_train_error_rounded
            print(" the first error is : ", first_error)
       

        # Выводим округленные ошибки на текущей эпохе
        if printAll:
            if X_test is not None:
                print(f"Epoch {epoch + 1}/{epochs}, Train Error: {total_train_error_rounded}, Test Error: {test_error_rounded}")
            else:
                print(f"Epoch {epoch + 1}/{epochs}, Train Error: {total_train_error_rounded}")
                
    if X_test is not None:    
        print(f" Finally , Train Error: {total_train_error_rounded}, Test Error: {test_error_rounded}")
        return W, b, train_errors,test_errors
    else:
         print(f" Finally , Train Error: {total_train_error_rounded}")
         return W, b, train_errors

# %%
W = np.random.rand(n)
W1 = W.copy()

W, b, train_errors, test_errors = gradient_class_train(200, X_train, y_train, W=W, b=b, learning_rate=0.01, batch_size = 1, X_test = X_test, y_test = y_test, shuffle = True)
# Out:
#  the first error is :  2
# Epoch 1/200, Train Error: 2, Test Error: 3
# Epoch 2/200, Train Error: 2, Test Error: 3
# Epoch 3/200, Train Error: 2, Test Error: 3
# Epoch 4/200, Train Error: 2, Test Error: 4
# Epoch 5/200, Train Error: 2, Test Error: 4
# Epoch 6/200, Train Error: 2, Test Error: 4
# Epoch 7/200, Train Error: 2, Test Error: 4
# Epoch 8/200, Train Error: 3, Test Error: 3
# Epoch 9/200, Train Error: 3, Test Error: 3
# Epoch 10/200, Train Error: 3, Test Error: 3
# Epoch 11/200, Train Error: 2, Test Error: 3
# Epoch 12/200, Train Error: 2, Test Error: 3
# Epoch 13/200, Train Error: 2, Test Error: 3
# Epoch 14/200, Train Error: 2, Test Error: 3
# Epoch 15/200, Train Error: 2, Test Error: 3
# Epoch 16/200, Train Error: 2, Test Error: 3
# Epoch 17/200, Train Error: 2, Test Error: 3
# Epoch 18/200, Train Error: 2, Test Error: 3
# Epoch 19/200, Train Error: 2, Test Error: 3
# Epoch 20/200, Train Error: 2, Test Error: 3
# Epoch 21/200, Train Error: 2, Test Error: 3
# Epoch 22/200, Train Error: 2, Test Error: 3
# Epoch 23/200, Train Error: 2, Test Error: 3
# Epoch 24/200, Train Error: 2, Test Error: 3
# Epoch 25/200, Train Error: 2, Test Error: 3
# Epoch 26/200, Train Error: 2, Test Error: 3
# Epoch 27/200, Train Error: 2, Test Error: 3
# Epoch 28/200, Train Error: 2, Test Error: 3
# Epoch 29/200, Train Error: 2, Test Error: 3
# Вам необходимо узнать предпочтения всех ее личностей, что бы подобрать хорошего мужа, который будет удовлетрорять всех ее личностей
#
# Для этого вы познакомили ее с 1000 кандидатами и узнали каким из ее личностей понравились каждые из этих вариантов
#
# будем считать что каждая из ее личностей это персептрон, на вход он получает параметры кандидата
# это будет [ на сколько он богат, красив, умен, силен, вежлив, верный, интересный ]
# соответственно каждая из ее личностей по разному интересуется этими различными параметрами и персептрон
# выдает 0 если не нравится, и 1 если нравится
##########

# %%
#################################################### Cоставляем Дано #######################################################################

# (решающий задачу такое знать не должен, это используется для составления дано по задаче и проверки эффективности решения
# составим модель предпочтений для личностей нашей дочери 

#[ богат, красив, умен, силен, вежлив, верный, интересный ]

# romantic girl
w1 = np.array([-10, 8, -2, 8, 10, 10, 8])
# intellectual girl
w2 = np.array([4, 8, 10, -8, 10, 9, 5])
# party girl
w3 = ([10, 10, -10, 6, -2, -8, 0])
# nervous girl
w4 = np.array([0, -8, 5, 5, 6, 10, -4])
# dominant girl
w5 = np.array([5, -10, 2, 5, -3, 6, 5])

W = [w1,w2,w3,w4,w5]

#по этим данным мы узнаем результаты самых разных парней и запомним их, это нам будет как ДАНО
# все характеристики будут от -1 до 1
X_parameters = np.random.rand(100,7)*2
X_parameters -= 1
#print(np.round(X_parameters, 4))


# узнаем какие парни понравились первой ее личности
#y_answers_w1 = np.array([perceptron_class_output(x, w1,0 ) for x in X_parameters])

# Создание двумерного массива Y_answers, где в Y_answers[0] находятся предпочтения по первой личности, в [4] по 5ой 
Y_answers = np.zeros((len(W), X_parameters.shape[0]), dtype=int)


for i, weights in enumerate(W):
    Y_answers[i] = np.array([perceptron_class_output(x, weights, 0) for x in X_parameters])

# %%
# Решение задачи 

# составим свою нейросеть с случайными весами, для будущего определения весов
W = np.random.rand(5,7)*20 -10

# попробуем рассчитать предпочтения разных личностей дочери согласно собранным данным
print("первая личность")
new_w1, b1, train_error = gradient_class_train(1000, X_parameters, Y_answers[0], W=W[0], b=0,
                                                           learning_rate=0.2, batch_size = 10, printAll = False)
print("вторая личность")
new_w2, b2, train_error = gradient_class_train(1000, X_parameters, Y_answers[1], W=W[1], b=0,
                                                           learning_rate=0.2, batch_size = 10, printAll = False)
print("третья личность")
new_w3, b3, train_error = gradient_class_train(1000, X_parameters, Y_answers[2], W=W[2], b=0,
                                                           learning_rate=0.2, batch_size = 10, printAll = False)
print("четвертая личность")
new_w4, b4, train_error = gradient_class_train(1000, X_parameters, Y_answers[3], W=W[3], b=0,
                                                           learning_rate=0.2, batch_size = 10, printAll = False)
print("пятая личность")
new_w5, b5, train_error = gradient_class_train(1000, X_parameters, Y_answers[4], W=W[4], b=0,
                                                           learning_rate=0.2, batch_size = 10, printAll = False)
# Out:
# первая личность
#  the first error is :  56
#  Finally , Train Error: 0
# вторая личность
#  the first error is :  54
#  Finally , Train Error: 0
# третья личность
#  the first error is :  42
#  Finally , Train Error: 0
# четвертая личность
#  the first error is :  46
#  Finally , Train Error: 0
# пятая личность
#  the first error is :  35
#  Finally , Train Error: 0

# %%
ratios = []


for i in range(len(new_w1)):
    ratio = w1[i] / new_w1[i]
    #print(abs(ratio))
    if(abs(ratio)>0):
        ratios.append(ratio)

# Вычисляем среднее значение отношений
average_ratio = sum(ratios) / len(ratios)

print("значения полученные от обучения \n", [round(x, 3) for x in new_w1])
print("реальные данные\n", w1+0.00)
print("значения умноженные на средний коеффицент отношения к реальным\n",[round(x, 2) for x in new_w1*average_ratio])

#отсюда можно заметить что попытка воссоздать модель нашей дочери по ответам получилась весьма неплохо
#так же тут видно свойство что все веса могут быть домножены на одинаковый коеффицент и мы получим одинаковую модель
# Out:
# значения полученные от обучения
#  [-3.169, 2.244, -0.473, 2.186, 3.141, 2.945, 2.59]
# реальные данные
#  [-10.   8.  -2.   8.  10.  10.   8.]
# значения умноженные на средний коеффицент отношения к реальным
#  [-10.99, 7.78, -1.64, 7.58, 10.9, 10.21, 8.98]

# %%
#зная то как устроены прредпочтения нашей дочери мы уже можем решить эту задачу аналитически (если она решаема)/
# однако мы попробуем ее решить ее через градиентный спуск

New_W = [new_w1,new_w2,new_w3,new_w4,new_w5]
New_B = [b1,b2,b3,b4,b5]

outputs = []

#возьмем мужа с случайными параметами
our_try = np.random.rand(7)-0.5

outputs = []
# узнаем нравится ли он личностям нашей дочери
for i, neuron_weights in enumerate(New_W):
    output_neuron = perceptron_class_output(our_try, neuron_weights, New_B[i])
    outputs.append(output_neuron)

print( "для парня с параметрами \n", [round(x, 3) for x in our_try])
print( "дочь отвечает таким образом: ", outputs)


# теперь нам нужно решить, что бы  sigmoid(np.dot(our_try, weights)) > 0.5
# это так же можно решить через градиентный спуск

def gradient_descent_for_husband(our_try, weights,biases ,learning_rate, iterations):
    for _ in range(iterations):
        gradient = np.zeros_like(our_try)
        for i, weight in enumerate(weights):
            result = perceptron_sigmoid_output(our_try, weight, biases[i])
            gradient += (result - 0.5) * result * (1 - result) * weight - biases[i] 
        our_try -= learning_rate * gradient
    return our_try


# Вызываем функцию градиентного спуска
print("\n оптимизируем параметры \n")
optimized_our_try = gradient_descent_for_husband(our_try, New_W, New_B, learning_rate = 0.2 , iterations = 100)

outputs = []
for i, neuron_weights in enumerate(New_W):
    output_neuron = perceptron_class_output(optimized_our_try, neuron_weights, New_B[i])
    outputs.append(output_neuron)
    
print( "для парня с параметрами \n", [round(x, 3) for x in optimized_our_try])
print( "дочь отвечает таким образом: ", outputs)
# Out:
# для парня с параметрами
#  [-0.444, 0.05, 0.24, -0.05, -0.4, 0.248, 0.159]
# дочь отвечает таким образом:  [1, 0, 0, 0, 1]
#
#  оптимизируем параметры
#
# для парня с параметрами
#  [23.412, 24.261, 24.152, 23.724, 23.528, 23.983, 24.051]
# дочь отвечает таким образом:  [1, 1, 1, 1, 1]

# %%
# таким образом мы решили задачу и нашли тот вариант (что не всегда удастстя с использованием градиентого спуска),
# который понравится всем, однако этот вариает весьма средний 
# и то что мы его нашли, лишь является одним из локальным минимумов, таким образом градиентным спуском мы находим не самый оптиммальный вариант
# такие задачи, где известны веса моделей и параметров не столь много, лучше решать аналитически
